# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/archive (1).zip")
df
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5           160
# 99         Audi     e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# ...

# %%
df.shape
# Out:
# (103, 14)

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'AccelSec', 'TopSpeed_KmH', 'Range_Km',
#        'Efficiency_WhKm', 'FastCharge_KmH', 'RapidCharge', 'PowerTrain',
#        'PlugType', 'BodyStyle', 'Segment', 'Seats', 'PriceEuro'],
#       dtype='object')

# %%
for col in df.columns:
  print(col)
# Out:
# Brand
# Model
# AccelSec
# TopSpeed_KmH
# Range_Km
# Efficiency_WhKm
# FastCharge_KmH
# RapidCharge
# PowerTrain
# PlugType
# BodyStyle
# Segment
# Seats
# PriceEuro

# %%
d = {
    'Brand':'Brand',
    'Model':'Model',
    'AccelSec':'AccelSec',
    'TopSpeed_KmH':'TopSpeed',
    'Range_Km':'Range',
    'Efficiency_WhKm':'Efficiency',
    'FastCharge_KmH':'FastCharge',
    'RapidCharge':'RapidCharge',
    'PowerTrain':'PowerTrain',
    'BodyStyle':'BodyStyle',

    'Seats':'Seats',

    }

# %%
df.rename(columns = d, inplace = True)
df.head()
# Out:
#          Brand                          Model  AccelSec  TopSpeed  Range  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6       233    450
# 1  Volkswagen                       ID.3 Pure      10.0       160    270
# 2    Polestar                               2       4.7       210    400
# 3         BMW                            iX3        6.8       180    360
# 4       Honda                              e        9.5       145    170
#
#    Efficiency FastCharge RapidCharge PowerTrain    PlugType  BodyStyle  \
# 0         161        940         Yes        AWD  Type 2 CCS      Sedan
# 1         167        250         Yes        RWD  Type 2 CCS  Hatchback
# 2         181        620         Yes        AWD  Type 2 CCS   Liftback
# 3         206        560         Yes        RWD  Type 2 CCS        SUV
# 4         168        190         Yes        RWD  Type 2 CCS  Hatchback
#
#   Segment  Seats  PriceEuro
# 0       D      5      55480
# 1       C      5      30000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Brand        103 non-null    object
#  1   Model        103 non-null    object
#  2   AccelSec     103 non-null    float64
#  3   TopSpeed     103 non-null    int64
#  4   Range        103 non-null    int64
#  5   Efficiency   103 non-null    int64
#  6   FastCharge   103 non-null    object
#  7   RapidCharge  103 non-null    object
#  8   PowerTrain   103 non-null    object
#  9   PlugType     103 non-null    object
#  10  BodyStyle    103 non-null    object
#  11  Segment      103 non-null    object
#  12  Seats        103 non-null    int64
#  13  PriceEuro    103 non-null    int64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 11.4+ KB

# %%
df['FastCharge']
# Out:
# 0      940
# 1      250
# 2      620
# 3      560
# 4      190
#       ...
# 98     440
# 99     540
# 100    440
# 101    450
# 102    480
# Name: FastCharge, Length: 103, dtype: object

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.isna()
# Out:
#      Brand  Model  AccelSec  TopSpeed  Range  Efficiency  FastCharge  \
# 0    False  False     False     False  False       False       False
# 1    False  False     False     False  False       False       False
# 2    False  False     False     False  False       False       False
# 3    False  False     False     False  False       False       False
# 4    False  False     False     False  False       False       False
# ..     ...    ...       ...       ...    ...         ...         ...
# 98   False  False     False     False  False       False       False
# 99   False  False     False     False  False       False       False
# 100  False  False     False     False  False       False       False
# 101  False  False     False     False  False       False       False
# 102  False  False     False     False  False       False       False
#
#      RapidCharge  PowerTrain  PlugType  BodyStyle  Segment  Seats  PriceEuro
# ...

# %%
df.isna().sum()
# Out:
# Brand          0
# Model          0
# AccelSec       0
# TopSpeed       0
# Range          0
# Efficiency     0
# FastCharge     0
# RapidCharge    0
# PowerTrain     0
# PlugType       0
# BodyStyle      0
# Segment        0
# Seats          0
# PriceEuro      0
# dtype: int64

# %%
plt.title('Brand and its topspeed')
plt.xlabel('Brand')
plt.ylabel('TopSpeed')
plt.xticks(rotation = 90)
plt.bar(df['Brand'],df['TopSpeed'],)
plt.show()

# %%
plt.title('Brand and its topspeed')
plt.xlabel('Brand')
plt.ylabel('Range')
plt.xticks(rotation = 90)
plt.scatter(df['Brand'],df['Range'],)
plt.show()

# %%
Brand_counts = df['Brand'].value_counts()
Brand_counts
# Out:
# Brand
# Tesla          13
# Audi            9
# Volkswagen      8
# Nissan          8
# Skoda           6
# Porsche         5
# Kia             5
# Renault         5
# BMW             4
# Ford            4
# Opel            3
# Hyundai         3
# Smart           3
# Byton           3
# Mercedes        3
# Honda           2
# Peugeot         2
# Fiat            2
# Volvo           1
# MG              1
# Lucid           1
# Polestar        1
# Mini            1
# Mazda           1
# Lexus           1
# Aiways          1
# Lightyear       1
# SEAT            1
# CUPRA           1
# Jaguar          1
# Citroen         1
# DS              1
# Sono            1
# Name: count, dtype: int64

# %%
plt.bar(Brand_counts.index, Brand_counts.values)
plt.xlabel('Brand')
plt.ylabel('Number Of Same Brands')
plt.title('How many same brands are buyed')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.pie(Brand_counts.values, labels = Brand_counts.index, shadow = True)
plt.axis('equal')
plt.show()

# %%
df[['Range', 'PriceEuro']]
# Out:
#      Range  PriceEuro
# 0      450      55480
# 1      270      30000
# 2      400      56440
# 3      360      68040
# 4      170      32997
# ..     ...        ...
# 98     330      45000
# 99     335      96050
# 100    325      50000
# 101    375      65000
# 102    400      62000
#
# [103 rows x 2 columns]

# %%
plt.bar(df['Range'],df['PriceEuro'])
plt.xlabel('Range')
plt.ylabel('PriceEuro')
plt.title('PriceEuro Based on Range')
plt.show()

# %%
x = df['Range']
y = df['PriceEuro']
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)

model =LinearRegression()
model.fit(x_train.values.reshape(-1, 1),y_train)
print(model.predict(x_test.values.reshape(-1, 1)))
print()
print(model.predict(y_test.values.reshape(-1, 1)))
# Out:
# [  9285.46305394  61395.94378656  55496.64408098 138086.83995911
#  103674.25834322  73194.54319773  54513.42746339  39765.17819944
#   39765.17819944  33865.87849386  56479.86069858  75160.97643292
#   35832.31172905  44681.26128742  79093.84290331  39765.17819944
#   53530.21084579  67295.24349214  71228.10996253  69261.67672734
#   77127.40966811  39765.17819944  59429.51055137  26983.36217068
#   52546.99422819  40748.39481703  51563.7776106   34849.09511145
#   22067.2790827   74177.75981532  74177.75981532]
#
# [ 4322656.76445069 13370216.07957556  8839553.90568995 14738853.61127018
#  29290459.55170142  8839553.90568995  7313011.7852093   7443386.30870263
#   7349390.80006038  5739275.26708402  8231139.46272111 12359469.39668615
#   8156414.99978376  5827371.47602068 10900375.93617264  6747465.58676768
#  18435748.09343379  8839553.90568995 12894339.23665876  8012668.73029112
#  20242900.23657653  6766736.63247257  8839553.90568995  6220461.47973585
# ...

# %%
df.head()
# Out:
#          Brand                          Model  AccelSec  TopSpeed  Range  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6       233    450
# 1  Volkswagen                       ID.3 Pure      10.0       160    270
# 2    Polestar                               2       4.7       210    400
# 3         BMW                            iX3        6.8       180    360
# 4       Honda                              e        9.5       145    170
#
#    Efficiency FastCharge RapidCharge PowerTrain    PlugType  BodyStyle  \
# 0         161        940         Yes        AWD  Type 2 CCS      Sedan
# 1         167        250         Yes        RWD  Type 2 CCS  Hatchback
# 2         181        620         Yes        AWD  Type 2 CCS   Liftback
# 3         206        560         Yes        RWD  Type 2 CCS        SUV
# 4         168        190         Yes        RWD  Type 2 CCS  Hatchback
#
#   Segment  Seats  PriceEuro
# 0       D      5      55480
# 1       C      5      30000
# ...

# %%
df[['TopSpeed', 'PriceEuro']]
# Out:
#      TopSpeed  PriceEuro
# 0         233      55480
# 1         160      30000
# 2         210      56440
# 3         180      68040
# 4         145      32997
# ..        ...        ...
# 98        160      45000
# 99        210      96050
# 100       200      50000
# 101       200      65000
# 102       190      62000
#
# [103 rows x 2 columns]

# %%
plt.bar(df['TopSpeed'],df['PriceEuro'])
plt.xlabel('TopSpeed')
plt.ylabel('PriceEuro')
plt.title('PriceEuro Based on Speed')
plt.show()

# %%
x = df['TopSpeed']
y = df['PriceEuro']
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)

model = LinearRegression()
model.fit(x_train.values.reshape(-1,1),y_train)
print(model.predict(x_test.values.reshape(-1, 1)))
print()
print(model.predict(y_test.values.reshape(-1,1)))
# Out:
# [ 27673.24513376  34519.49375667  68750.73687124  44788.86669104
#  102981.9799858   24250.12082231  41365.74237959  34519.49375667
#   41365.74237959  55058.23962541  41365.74237959  41365.74237959
#   55058.23962541  20826.99651085  61904.48824832  75596.98549415
#   75596.98549415 102981.9799858   34519.49375667  55058.23962541
#   55058.23962541  34519.49375667  37942.61806813  31096.36944522
#   75596.98549415  61904.48824832  34519.49375667  85866.35842852
#  102981.9799858   41365.74237959  34519.49375667]
#
# [4.82875644e+07 1.98859020e+07 5.43218479e+07 2.35233139e+07
#  5.88027177e+07 1.99461490e+07 2.56052581e+07 2.38936959e+07
#  2.04705716e+07 3.07399446e+07 3.07399446e+07 2.42873552e+07
#  4.29947296e+07 2.59475705e+07 4.60467872e+07 6.56900438e+07
#  6.41496378e+07 7.04105322e+07 2.58791080e+07 3.20407318e+07
#  3.75861932e+07 2.46173444e+07 2.34829210e+07 2.25223923e+07
#  5.12786904e+07 4.37478170e+07 1.01940930e+08 3.16847269e+07
# ...

# %%
df.head()
# Out:
#          Brand                          Model  AccelSec  TopSpeed  Range  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6       233    450
# 1  Volkswagen                       ID.3 Pure      10.0       160    270
# 2    Polestar                               2       4.7       210    400
# 3         BMW                            iX3        6.8       180    360
# 4       Honda                              e        9.5       145    170
#
#    Efficiency FastCharge RapidCharge PowerTrain    PlugType  BodyStyle  \
# 0         161        940         Yes        AWD  Type 2 CCS      Sedan
# 1         167        250         Yes        RWD  Type 2 CCS  Hatchback
# 2         181        620         Yes        AWD  Type 2 CCS   Liftback
# 3         206        560         Yes        RWD  Type 2 CCS        SUV
# 4         168        190         Yes        RWD  Type 2 CCS  Hatchback
#
#   Segment  Seats  PriceEuro
# 0       D      5      55480
# 1       C      5      30000
# ...

# %%
df['BodyStyle'].unique()
# Out:
# array(['Sedan', 'Hatchback', 'Liftback', 'SUV', 'Pickup', 'MPV', 'Cabrio',
#        'SPV', 'Station'], dtype=object)

# %%
Body_types = df['BodyStyle'].value_counts()
Body_types
# Out:
# BodyStyle
# SUV          45
# Hatchback    32
# Sedan        10
# Liftback      5
# Pickup        3
# Cabrio        3
# SPV           3
# MPV           1
# Station       1
# Name: count, dtype: int64

# %%
len(Body_types)
# Out:
# 9

# %%
plt.pie(Body_types.values, labels = Body_types.index, shadow = True, explode = [0.05,0.05, 0.05, 0.05, 0.05, 0.05,0.05,0.05,0.05])
plt.axis('equal')
plt.show()

# %%
df.head(2)
# Out:
#          Brand                          Model  AccelSec  TopSpeed  Range  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6       233    450
# 1  Volkswagen                       ID.3 Pure      10.0       160    270
#
#    Efficiency FastCharge RapidCharge PowerTrain    PlugType  BodyStyle  \
# 0         161        940         Yes        AWD  Type 2 CCS      Sedan
# 1         167        250         Yes        RWD  Type 2 CCS  Hatchback
#
#   Segment  Seats  PriceEuro
# 0       D      5      55480
# 1       C      5      30000

# %%
df[['Efficiency','PriceEuro']]
# Out:
#      Efficiency  PriceEuro
# 0           161      55480
# 1           167      30000
# 2           181      56440
# 3           206      68040
# 4           168      32997
# ..          ...        ...
# 98          191      45000
# 99          258      96050
# 100         194      50000
# 101         232      65000
# 102         238      62000
#
# [103 rows x 2 columns]

# %%
plt.title("Based on Efficiency of Vechicle we can calculate Price ")
plt.xlabel('Efficiency of Vehicle')
plt.ylabel('Price in Euros')
plt.scatter(df['Efficiency'],df['PriceEuro'])
plt.show()

# %%
x = df['Efficiency']
y = df['PriceEuro']
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)

model =LinearRegression()
model.fit(x_train.values.reshape(-1, 1),y_train)
print(model.predict(x_test.values.reshape(-1, 1)))
print()
print(model.predict(y_test.values.reshape(-1, 1)))
# Out:
# [46821.20169361 82823.1756382  51417.19836738 67886.18644842
#  51417.19836738 53332.19698146 48353.20058486 52949.19725864
#  52183.19781301 48353.20058486 49502.19975331 58311.19337805
#  69418.18533968 45289.20280235 49885.19947612 48353.20058486
#  58311.19337805 59460.1925465  47587.20113923 52566.19753583
#  47587.20113923 82057.17619257 56013.19504116 58694.19310087
#  51800.1980902  52949.19725864 57928.19365524 58311.19337805
#  71333.18395376 49502.19975331 42608.20474264]
#
# [11146919.16831473 36771132.62352208  9392397.43809972 26622022.96865033
#   8421493.14076398 14346498.85271031 14499698.74183627 13144262.72279437
#  12487418.19816684 12621851.10087487 17218996.77382198 17946696.24717027
#  69223082.13735045 15608482.93938537 14245769.92561    13350699.5733916
#  14537998.71411776 41846644.950265   12623000.10004331 13388999.54567309
#   8188246.30956971 17218996.77382198 37131152.36296808 39411915.71233074
# ...

# %%
df.head(3)
# Out:
#          Brand                          Model  AccelSec  TopSpeed  Range  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6       233    450
# 1  Volkswagen                       ID.3 Pure      10.0       160    270
# 2    Polestar                               2       4.7       210    400
#
#    Efficiency FastCharge RapidCharge PowerTrain    PlugType  BodyStyle  \
# 0         161        940         Yes        AWD  Type 2 CCS          1
# 1         167        250         Yes        RWD  Type 2 CCS  Hatchback
# 2         181        620         Yes        AWD  Type 2 CCS   Liftback
#
#   Segment  Seats  PriceEuro
# 0       D      5      55480
# 1       C      5      30000
# 2       D      5      56440

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Brand        103 non-null    object
#  1   Model        103 non-null    object
#  2   AccelSec     103 non-null    float64
#  3   TopSpeed     103 non-null    int64
#  4   Range        103 non-null    int64
#  5   Efficiency   103 non-null    int64
#  6   FastCharge   103 non-null    int64
#  7   RapidCharge  103 non-null    object
#  8   PowerTrain   103 non-null    object
#  9   PlugType     103 non-null    object
#  10  BodyStyle    103 non-null    object
#  11  Segment      103 non-null    object
#  12  Seats        103 non-null    int64
#  13  PriceEuro    103 non-null    int64
# dtypes: float64(1), int64(6), object(7)
# memory usage: 11.4+ KB
